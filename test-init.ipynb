# %%
from algorithm_trading import *
import requests
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from algorithm_trading import *
#       2 import requests
#
# File ~/dev/module-algorithm_trading/algorithm_trading/__init__.py:3
#       1 from .hantoo_consts import *
#       2 from .hantoo_token import *
# ----> 3 from .hantoo_connector import *
#       5 if __name__ == "__main__":
#       6     get_response_token()
#
# File ~/dev/module-algorithm_trading/algorithm_trading/hantoo_connector.py:3
#       1 import requests
#       2 import json
# ----> 3 from .hantoo_consts import HANTOO_URL_TOKEN, HANTOO_APP_KEY, HANTOO_APP_SECRET, HANTOO_CANO, HANTOO_PRDT_CD, HANTOO_URL_BALANCE, DATA_TOKEN
#       6 def get_response_token():
#       7     url_token = HANTOO_URL_TOKEN
#
# ...

# %%
HANTOO_APP_KEY, HANTOO_APP_SECRET, HANTOO_URL_TOKEN, HANTOO_CANO, HANTOO_PRDT_CD
# Out:
# ('PS9P2w07eftCFU4S3osbkh29kG4r8JdIWdP6',
#  'zMyBg2iSAFontUj3GREqwn7dogXJgF28NgG6Vg758k+Vs16jrRGuIfKDrsyhR2goz7oJ4+YjatF+t0H2DY0E73IPRAVRk/eJGKA0jRVDOX0aRZQejW1jccjQGzGLP8QZIManDgcOYXRXKW1kfRTP4fG9SYrXX5LZeKpXCeMvMQlyX49K0Ss=',
#  'https://openapi.koreainvestment.com:9443/oauth2/tokenP',
#  '68317378',
#  '01')

# %%
DATA_TOKEN
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6IjJhOWM5ZDNmLTJlOWMtNDdlMC05NzMwLWQzNjEwNmI5YzFkZCIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTczNjM0OTc5OCwiaWF0IjoxNzM2MjYzMzk4LCJqdGkiOiJQUzlQMncwN2VmdENGVTRTM29zYmtoMjlrRzRyOEpkSVdkUDYifQ.KBZ8_htxsT_ZJyNX2bWG1A74WH3MKfdrxdXT03YnvI5kDq0rLFVXAGl_rEQpK7lmr4jl5D3NlGjWSXAZ6OIkDg',
#  'access_token_token_expired': '2025-01-09 00:23:18',
#  'token_type': 'Bearer',
#  'expires_in': 86400}

# %%
token_type = DATA_TOKEN['token_type']
token = DATA_TOKEN['access_token']
token_type, token
# Out:
# ('Bearer',
#  'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6IjJhOWM5ZDNmLTJlOWMtNDdlMC05NzMwLWQzNjEwNmI5YzFkZCIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTczNjM0OTc5OCwiaWF0IjoxNzM2MjYzMzk4LCJqdGkiOiJQUzlQMncwN2VmdENGVTRTM29zYmtoMjlrRzRyOEpkSVdkUDYifQ.KBZ8_htxsT_ZJyNX2bWG1A74WH3MKfdrxdXT03YnvI5kDq0rLFVXAGl_rEQpK7lmr4jl5D3NlGjWSXAZ6OIkDg')

# %%
def get_response_balance(tr_id, data_token=DATA_TOKEN):
    token_type = data_token['token_type']
    token = data_token['access_token']
    url = HANTOO_URL_BALANCE
    headers = {
        "content-type": "application/json; charset=utf-8",
        "authorization": f"{token_type} {token}",
        "appkey": HANTOO_APP_KEY,
        "appsecret": HANTOO_APP_SECRET,
        "tr_id": tr_id
    }
    params = {
        "CANO": HANTOO_CANO,
        "ACNT_PRDT_CD": HANTOO_PRDT_CD,
        "OVRS_EXCG_CD": "NASD",
        "TR_CRCY_CD": "USD",
        "CTX_AREA_FK200": "",
        "CTX_AREA_NK200": ""
    }
    response = requests.get(url, headers=headers, params=params)
    return response

# %%
response = get_response_balance(tr_id=REAL_TRADING)
response.json()
# Out:
# {'ctx_area_fk200': '                                                                                                                                                                                                        ',
#  'ctx_area_nk200': '                                                                                                                                                                                                        ',
#  'output1': [{'cano': '68317378',
#    'acnt_prdt_cd': '01',
#    'prdt_type_cd': '512',
#    'ovrs_pdno': 'AAPL',
#    'ovrs_item_name': '애플',
#    'frcr_evlu_pfls_amt': '669.580100',
#    'evlu_pfls_rt': '123.66',
#    'pchs_avg_pric': '108.2940',
#    'ovrs_cblc_qty': '5',
#    'ord_psbl_qty': '5',
#    'frcr_pchs_amt1': '541.46990',
#    'ovrs_stck_evlu_amt': '1211.05000000',
#    'now_pric2': '242.210000',
#    'tr_crcy_cd': 'USD',
#    'ovrs_excg_cd': 'NASD',
#    'loan_type_cd': '10',
#    'loan_dt': '',
#    'expd_dt': ''},
# ...

# %%
url = "https://openapi.koreainvestment.com:9443/uapi/overseas-stock/v1/trading/inquire-psamount"

headers = {
    "content-type": "application/json; charset=utf-8",
    "authorization": f"{token_type} {token}",
    "appkey": HANTOO_APP_KEY,
    "appsecret": HANTOO_APP_SECRET,
    "tr_id": "TTTS3012R"
}

params = {
    "CANO": HANTOO_CANO,          # 계좌번호 앞 8자리
    "ACNT_PRDT_CD": HANTOO_PRDT_CD,        # 계좌상품코드 뒤 2자리
    "OVRS_EXCG_CD": "NASD",      # 거래소코드 (예: NASD-나스닥)
    "OVRS_ORD_UNPR": "150.00",   # 주문단가 (예: 150달러)
    "ITEM_CD": "AAPL",            # 종목코드 (예: AAPL-애플)
    "TR_CRCY_CD": "USD",         # 거래통화코드
    "CTX_AREA_FK200": "",        # 연속조회검색조건(처음조회시 공백)
    "CTX_AREA_NK200": ""         # 연속조회키(처음조회시 공백)
}

response = requests.get(url, headers=headers, params=params)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'ctx_area_fk200': '                                                                                                                                                                                                        ',
#  'ctx_area_nk200': '                                                                                                                                                                                                        ',
#  'output1': [{'cano': '68317378',
#    'acnt_prdt_cd': '01',
#    'prdt_type_cd': '512',
#    'ovrs_pdno': 'AAPL',
#    'ovrs_item_name': '애플',
#    'frcr_evlu_pfls_amt': '669.580100',
#    'evlu_pfls_rt': '123.66',
#    'pchs_avg_pric': '108.2940',
#    'ovrs_cblc_qty': '5',
#    'ord_psbl_qty': '5',
#    'frcr_pchs_amt1': '541.46990',
#    'ovrs_stck_evlu_amt': '1211.05000000',
#    'now_pric2': '242.210000',
#    'tr_crcy_cd': 'USD',
#    'ovrs_excg_cd': 'NASD',
#    'loan_type_cd': '10',
#    'loan_dt': '',
#    'expd_dt': ''},
# ...

# %%
vars(response)
# Out:
# {'_content': b'{"ctx_area_fk200":"                                                                                                                                                                                                        ","ctx_area_nk200":"                                                                                                                                                                                                        ","output1":[{"cano":"68317378","acnt_prdt_cd":"01","prdt_type_cd":"512","ovrs_pdno":"AAPL","ovrs_item_name":"\xec\x95\xa0\xed\x94\x8c","frcr_evlu_pfls_amt":"669.580100","evlu_pfls_rt":"123.66","pchs_avg_pric":"108.2940","ovrs_cblc_qty":"5","ord_psbl_qty":"5","frcr_pchs_amt1":"541.46990","ovrs_stck_evlu_amt":"1211.05000000","now_pric2":"242.210000","tr_crcy_cd":"USD","ovrs_excg_cd":"NASD","loan_type_cd":"10","loan_dt":"","expd_dt":""},{"cano":"68317378","acnt_prdt_cd":"01","prdt_type_cd":"512","ovrs_pdno":"AMD","ovrs_item_name":"AMD","frc
# ...

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<html><meta http-equiv="refresh" content="0; url=https://securities.koreainvestment.com/error/error.jsp"></meta><body></body></html>'

# %%
response.content
# Out:
# b'<html><meta http-equiv="refresh" content="0; url=https://securities.koreainvestment.com/error/error.jsp"></meta><body></body></html>'

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
url = "https://openapi.koreainvestment.com:9443/uapi/overseas-stock/v1/trading/inquire-balance"

headers = {
    "content-type": "application/json; charset=utf-8",
    "authorization": f"{token_type} {token}",
    "appkey": HANTOO_APP_KEY,
    "appsecret": HANTOO_APP_SECRET,
    "tr_id": "TTTS3012R"
}

params = {
    "CANO": HANTOO_CANO,
    "ACNT_PRDT_CD": HANTOO_PRDT_CD,
    "OVRS_EXCG_CD": "NASD",
    "TR_CRCY_CD": "USD",
    "CTX_AREA_FK200": "",
    "CTX_AREA_NK200": ""
}

response = requests.get(url, headers=headers, params=params)

# %%
response.json()
# Out:
# {'ctx_area_fk200': '                                                                                                                                                                                                        ',
#  'ctx_area_nk200': '                                                                                                                                                                                                        ',
#  'output1': [{'cano': '68317378',
#    'acnt_prdt_cd': '01',
#    'prdt_type_cd': '512',
#    'ovrs_pdno': 'AAPL',
#    'ovrs_item_name': '애플',
#    'frcr_evlu_pfls_amt': '681.780100',
#    'evlu_pfls_rt': '125.91',
#    'pchs_avg_pric': '108.2940',
#    'ovrs_cblc_qty': '5',
#    'ord_psbl_qty': '5',
#    'frcr_pchs_amt1': '541.46990',
#    'ovrs_stck_evlu_amt': '1223.25000000',
#    'now_pric2': '244.650000',
#    'tr_crcy_cd': 'USD',
#    'ovrs_excg_cd': 'NASD',
#    'loan_type_cd': '10',
#    'loan_dt': '',
#    'expd_dt': ''},
# ...

# %%
import requests
import json

def fetch_data_token():
    url_token = HANTOO_URL_TOKEN
    data_for_token = {
        "grant_type": "client_credentials",
        "appkey": HANTOO_APP_KEY,
        "appsecret": HANTOO_APP_SECRET
    }
    headers = {
        "content-type": "application/json"
    }
    response = requests.post(url_token, data=json.dumps(data_for_token), headers=headers)
    data = response.json()
    return data

# %%
data_token = fetch_data_token()
data_token
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6IjJhOWM5ZDNmLTJlOWMtNDdlMC05NzMwLWQzNjEwNmI5YzFkZCIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTczNjM0OTc5OCwiaWF0IjoxNzM2MjYzMzk4LCJqdGkiOiJQUzlQMncwN2VmdENGVTRTM29zYmtoMjlrRzRyOEpkSVdkUDYifQ.KBZ8_htxsT_ZJyNX2bWG1A74WH3MKfdrxdXT03YnvI5kDq0rLFVXAGl_rEQpK7lmr4jl5D3NlGjWSXAZ6OIkDg',
#  'access_token_token_expired': '2025-01-09 00:23:18',
#  'token_type': 'Bearer',
#  'expires_in': 86400}

# %%
token = data_token['access_token']
token_type = data_token['token_type']
token_type, token
# Out:
# ('Bearer',
#  'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJ0b2tlbiIsImF1ZCI6IjJhOWM5ZDNmLTJlOWMtNDdlMC05NzMwLWQzNjEwNmI5YzFkZCIsInByZHRfY2QiOiIiLCJpc3MiOiJ1bm9ndyIsImV4cCI6MTczNjM0OTc5OCwiaWF0IjoxNzM2MjYzMzk4LCJqdGkiOiJQUzlQMncwN2VmdENGVTRTM29zYmtoMjlrRzRyOEpkSVdkUDYifQ.KBZ8_htxsT_ZJyNX2bWG1A74WH3MKfdrxdXT03YnvI5kDq0rLFVXAGl_rEQpK7lmr4jl5D3NlGjWSXAZ6OIkDg')

# %%
data_token = response.json()
data_token
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data_token = response.json()
#       2 data_token
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
import requests

url = "https://openapi.koreainvestment.com:9443/uapi/overseas-stock/v1/trading/inquire-balance"

headers = {
    "content-type": "application/json; charset=utf-8",
    "authorization": f"{token_type} {token}",
    "appkey": HANTOO_APP_KEY,
    "appsecret": HANTOO_APP_SECRET,
    "tr_id": "TTTS3012R"
}

params = {
    "CANO": "12345678",
    "ACNT_PRDT_CD": "01",
    "OVRS_EXCG_CD": "NASD",
    "TR_CRCY_CD": "USD",
    "CTX_AREA_FK200": "",
    "CTX_AREA_NK200": ""
}

response = requests.get(url, headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'rt_cd': '2',
#  'msg_cd': 'OPSQ2000',
#  'msg1': 'ERROR : INPUT INVALID_CHECK_ACNO'}
